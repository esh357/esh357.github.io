# %% [markdown]
# Ideas of visualization:
# -

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_excel("WALS_dataset.xlsx", header=1)

# %%
data.head(10)
# Out:
#   wals_code iso_code glottocode                   Name   latitude   longitude  \
# 0       aab      NaN        NaN          Arapesh (Abu)  -3.450000  142.950000
# 1       aar      aiw   aari1239                   Aari   6.000000   36.583333
# 2       aba      aau   abau1245                   Abau  -4.000000  141.250000
# 3       abb      shu   chad1249  Arabic (Abbéché Chad)  13.833333   20.833333
# 4       abd      abi   abid1235                 Abidji   5.666667   -4.583333
# 5       abe      apc   nort3139        Arabic (Beirut)  33.916667   35.500000
# 6       abh      abv   baha1259       Arabic (Bahrain)  26.000000   50.500000
# 7       abi      axb   abip1241                 Abipón -29.000000  -61.000000
# 8       abk      abk   abkh1244                 Abkhaz  43.083333   41.000000
# 9       abm      akz   alab1237                Alabama  32.333333  -87.416667
#
#                  genus               family      macroarea countrycodes  ...  \
# ...

# %%
data[data.Name == 'German'].iloc[:,:10]
# Out:
#     wals_code iso_code glottocode    Name  latitude  longitude     genus  \
# 732       ger      deu   stan1295  German      52.0       10.0  Germanic
#
#             family macroarea countrycodes
# 732  Indo-European   Eurasia     AT DE CH

# %%
data[data.countrycodes == 'DE'].iloc[:,:10]
# Out:
#      wals_code iso_code glottocode                      Name   latitude  \
# 573        dge      gsg   germ1281  Deutsche Gebärdensprache  52.000000
# 671        fea      frs   east2288         Frisian (Eastern)  53.583333
# 682        fno      frr   nort2626           Frisian (North)  54.500000
# 721        gbl      deu   stan1295           German (Berlin)  52.500000
# 736        gha      deu   stan1295         German (Hannover)  52.416667
# 754        gma      deu   stan1295     German (Mansfeldisch)  51.583333
# 795        gth      deu   stan1295       German (Thuringian)  51.000000
# 816        gwe      wep   west2356      German (Westphalian)  52.000000
# 1307       lge      nds   nort2627                Low German  53.000000
# 1907       plb      pox   pola1255                  Polabian  51.000000
# 2154       sou      hsb   uppe1395           Sorbian (Upper)  51.833333
# 2162       srb      hsb   sorb1249                   Sorbian  51.500000
# ...

# %%
data[data["macroarea"].isnull()]
# Out:
#      wals_code iso_code glottocode                                 Name  \
# 0          aab      NaN        NaN                        Arapesh (Abu)
# 190        ayo      NaN        NaN                               Ayomán
# 202        bah      xir   xiri1243                              Xiriana
# 243        bfg      NaN        NaN                      Berber (Figuig)
# 984        joh      NaN        NaN                               Johari
# 990        jua      NaN        NaN                                 Juat
# 1046       keu      NaN        NaN                   Kenyah (Uma' Lung)
# 1048       kfc      NaN        NaN             Kriol (Fitzroy Crossing)
# 1228       kua      NaN        NaN                               Kualan
# 1308       lgh      NaN        NaN       Lughat al-Isharat al-Lubnaniya
# 1427       mdm      NaN   west2443                             Madimadi
# 1486       mkh      NaN        NaN                   Mongol (Khamnigan)
# ...

# %%
np.unique(data["countrycodes"].astype('str'))
# Out:
# array(['AF', 'AF PK', 'AF PK TJ', 'AF TJ', 'AF UZ', 'AL RS', 'AM', 'AN',
#        'AO', 'AO CD', 'AO NA', 'AR', 'AS WS', 'AT', 'AT DE CH', 'AU',
#        'AZ', 'AZ IR', 'BA', 'BD', 'BD IN MM', 'BE', 'BF', 'BF CI',
#        'BF GH', 'BF ML', 'BG', 'BH', 'BI', 'BJ', 'BJ GH TG', 'BO',
#        'BO AR', 'BO CL AR', 'BR', 'BR CO', 'BR GY', 'BR PE', 'BR SR',
#        'BR VR', 'BT IN', 'BT NP IN', 'BW', 'BW AO NA', 'BW NA', 'BW ZA',
#        'BY', 'BZ', 'BZ GT HN', 'CA', 'CA US', 'CD', 'CD CF', 'CD UG',
#        'CD ZM', 'CF', 'CF CD', 'CF CG', 'CG', 'CH', 'CH FR', 'CI',
#        'CI SN BF ML', 'CL', 'CM', 'CM CF', 'CM NG', 'CM TD', 'CN',
#        'CN MM', 'CN MN', 'CN TH MM', 'CO', 'CO BR', 'CO EC', 'CO PA',
#        'CO PE', 'CR', 'CY', 'CZ', 'DE', 'DE AT', 'DE NL', 'DK', 'DZ',
#        'DZ MA', 'EC', 'EC CO', 'EC PE', 'EE', 'EG', 'EG SD', 'ER',
#        'ER ET', 'ER ET DJ', 'ER SD', 'ES', 'ET', 'ET KE', 'ET SD', 'FI',
# ...

# %%
np.unique(data.iloc[:,3])
# Out:
# array(['!Xun (Ekoka)', '!Xóõ', "'Are'are", ..., 'rGyalrong (Caodeng)',
#        'Émérillon', 'Ömie'], dtype=object)

# %%
len(np.unique(data["Name"]))
# Out:
# 2679

# %%
len(np.unique(data["family"]))
# Out:
# 256

# %%
(data.shape)
# Out:
# (2679, 202)

# %%
(data.columns)[:10]
# Out:
# Index(['wals_code', 'iso_code', 'glottocode', 'Name', 'latitude', 'longitude',
#        'genus', 'family', 'macroarea', 'countrycodes'],
#       dtype='object')

# %%
data.iloc[:,0]
# Out:
# 0       aab
# 1       aar
# 2       aba
# 3       abb
# 4       abd
#        ...
# 2674    zte
# 2675    zul
# 2676    zun
# 2677    zya
# 2678    zzo
# Name: wals_code, Length: 2679, dtype: object

# %%
np.unique(data["family"])
# Out:
# array(['Afro-Asiatic', 'Aikaná', 'Ainu', 'Alacalufan', 'Algic', 'Altaic',
#        'Andoke', 'Anson Bay', 'Anêm', 'Arauan', 'Araucanian', 'Arawakan',
#        'Atakapa', 'Austro-Asiatic', 'Austronesian', 'Awin-Pare',
#        'Aymaran', 'Baining-Taulil', 'Bangime', 'Barbacoan', 'Basque',
#        'Beothuk', 'Berta', 'Betoi', 'Border', 'Bororoan', 'Bosavi',
#        'Bulaka River', 'Bunuban', 'Burushaski', 'Cacua-Nukak', 'Caddoan',
#        'Cahuapanan', 'Camsá', 'Candoshi', 'Cariban', 'Cayuvava',
#        'Central Sudanic', 'Chapacura-Wanham', 'Chibchan', 'Chimakuan',
#        'Chimúan', 'Chiquito', 'Chitimacha', 'Choco', 'Cholon', 'Chon',
#        'Chukotko-Kamchatkan', 'Chumash', 'Coahuiltecan', 'Cofán',
#        'Comecrudan', 'Cuitlatec', 'Dagan', 'Darwin Region', 'Dogon',
#        'Dravidian', "East Bird's Head", 'East Bougainville',
#        'East Geelvink Bay', 'East Strickland', 'Eastern Daly',
#        'Eastern Sudanic', 'Eleman', 'Eskimo-Aleut', 'Esselen', 'Fur',
# ...

# %%
np.unique(data["genus"])
# Out:
# array(['=|Hoan', 'Adamawa', 'Aikaná', 'Ainu', 'Alacalufan', 'Alawa',
#        'Albanian', 'Aleut', 'Algonquian', 'Alsea', 'Alto-Orinoco',
#        'Amuzgoan', 'Andoke', 'Angan', 'Anindilyakwa', 'Annaberg',
#        'Anson Bay', 'Anêm', 'Arauan', 'Araucanian', 'Arhuacic', 'Arikem',
#        'Armenian', 'Aslian', 'Asmat-Kamoro', 'Atakapa', 'Atayalic',
#        'Athapaskan', 'Avar-Andic-Tsezic', 'Awin-Pare', 'Awju-Dumut',
#        'Aymaran', 'Aztecan', 'Bahnaric', 'Bahuanic', 'Bai', 'Baining',
#        'Baltic', 'Bangime', 'Bantoid', 'Barbacoan', 'Barito', 'Basque',
#        'Batanic', 'Beja', 'Bella Coola', 'Beothuk', 'Berber', 'Berta',
#        'Betoi', 'Bilic', 'Bilua', 'Binanderean', 'Biu-Mandara', 'Bodic',
#        'Bodo-Garo', 'Bolivia-Parana', 'Bongo-Bagirmi', 'Boran', 'Border',
#        'Bororoan', 'Bosavi', 'Botin', 'Botocudo', 'Bringen',
#        'Bulaka River', 'Bunuban', 'Burarran', 'Burmese-Lolo',
#        'Burushaski', 'Cacua-Nukak', 'Caddoan', 'Cahita', 'Cahuapanan',
# ...
